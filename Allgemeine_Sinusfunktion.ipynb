# %% [markdown]
# # Allgemeine Sinusfunktion
#
# \begin{equation}
# y(t)=A*sin(\omega*t+\phi)
# \end{equation}

# %% [markdown]
# ## Amplitude
#
# - $A$ ... Amplitude, A e R
#
# - $A > 1$ ... Streckung in y-Richtung
#
# - $0 < A < 1$ ... Stauchung in y-Richtung
#
# - $A < 0$ ... Spiegelung an der x-Achse + Stauchung bzw. Streckung

# %% [markdown]
# ## Kreisfrequenz
#
# - $\omega$ ...Kreisfrequenz; T...Periode(Umlaufzeit in einem Kreis)
#
# - $T=2\pi/\omega$
#
# - $\omega>1$ ...Periode wird verkürzt
#
# - $0<\omega<1$ ...Periode wird vergrößert
#
# - $\omega<0$ ... Cosinus

# %% [markdown]
# ## Phasenwinkel
#
# - $\phi$ ...Nullphasenwinkel | $\omega*t+\phi$ ...Phasenwinkel
#
# - $\phi<0$ ...rechtsverschiebung auf der x-Achse
#
# - $\phi>0$ ...linksverschiebung auf der x-Achse
#
# - $\phi=+\pi/2$ ...Cosinus

# %% [markdown]
# ## Funktionsplotter

# %%
import matplotlib.pyplot as plt
import numpy as np


def sinusplot(A, w, p):
    """
    A = Amplitude
    w = Winkelgeschwindigkeit
    p = Phasenwinkel
    """
    # Grundmenge
    t = np.arange(0.0, np.pi * 2., 0.01)

    # Formel
    y = A * np.sin(w *  t + p)

    # Plot
    
    fig, ax = plt.subplots()
    fig.set_dpi(150)
    ax.plot(t, y)

    ax.set(
       xlabel='time(t)',
       ylabel='Amplitude(y)',
       title='Sinuskurve A={0:0.3f}, w={1:0.3f}, p={2:0.3f}'.format(A, w, p),)
    ax.grid()
    plt.show()

# %% [markdown]
# ## Bsp.

# %%
sinusplot(A=1.3, w=2.4, p=np.pi/3.1)

# %% [markdown]
# ## Achtung bei Nullstellen
#
# - $t_0=-\frac{\phi}{\omega}$
#
# - $\frac{\pi}{2}=\frac{\phi}{1}=-\phi$ ==) $\phi=-\frac{\pi}{2}$
#
# - $\frac{\pi}{4}= -\frac{\phi}{2}$  |/2
#
# - $\frac{\pi}{2}=-\phi$ ==) $\phi=\frac{\pi}{2}$

# %% [markdown]
# ## bsp. Allgemeine Sinusfunktion aus Grundsinus
#
# 1. Grundsinus: $sin(t)$
#
# 2. +Winkelgeschwindigkeit: $sin(\omega*t)$
#
# 3. +Phasenverschiebung: $sin(\omega*t+\phi)$
#
# 4. +Amplitude: $A*sin(\omega*t+\phi)$
#
# Formel: $y=\color{red}{1,5(A)}*sin(\color{blue}{2(\omega)}*t+\color{green}{\frac{3}{\pi}}$

# %% [markdown]
# ## 1.) $y=sin(t)$

# %%
sinusplot(A=1, w=1, p=0)

# %% [markdown]
# ## 2.) $y=sin(\color{blue}{2(\omega)}*t)$

# %%
sinusplot(A=1, w=2, p=0)

# %% [markdown]
# ## 3.) $y=sin(\color{blue}{2(\omega)}*t+\color{green}{\frac{3}{\pi}})$

# %%
sinusplot(A=1, w=2, p=3/np.pi)

# %% [markdown]
# ## 4.) $y=\color{red}{1,5(A)}*sin(\color{blue}{2(\omega)}*t+\color{green}{\frac{3}{\pi}}$

# %%
sinusplot(A=1.5, w=2, p=3/2)

# %%
sinusplot(A=1, w=0, p=0)
